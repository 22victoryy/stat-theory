unbiased = UnBiasedVarianceList(a)

# np.mean(unbiased)
        
# def UnBiasedVariableBias(data):
#     """
#     """
# #     theta = 2
# #     print(np.mean(data))
# #     bias = np.mean(data) - theta
# #     return bias
#     actual = 2 # Estimate population sampling of 2, as indicated on the handout
#     value = None
#     l = []
#     for i in range(len(data)):
#         value = data[i] - actual
# #         print(value)
#         l.append(value)
#     return l

unbias = np.mean(unbiased) - theta

print("Bias[S^2]:")
print(unbias)

# theta_hat = UnBiasedVariableBias(unbiased)
# print(theta_hat)

# np.mean(theta_hat) - theta

print('-------------------------------------------------')

print ("Bias[S^2]: {}, approximately zero. For instance, the value is very close to zero, which \
approximatly satisfies the unbiasedness condition where the expectation of estimator of theta minus theta is \
equal to zero. Therefore, S^2, consistent with the definition, is unbiased.".format(unbias))
# Out:
# Bias[S^2]:
# 4.440892098500626e-16
# -------------------------------------------------
# Bias[S^2]: 4.440892098500626e-16, approximately zero. For instance, the value is very close to zero, which approximatly satisfies the unbiasedness condition where the expecation of estimator of theta minus theta is equal to zero. Therefore, S^2, consistent with the definition, is unbiased.

# %%
def BiasedVarianceList(data):
    # finds the variance of a given set of numbers
    l = []
    for i in range(len(data)):
        xbar = st.mean(data[i])
        var = sum([(x - xbar)**2 for x in data[i]])/(len(data[i]))
        l.append(var)
    return l
# myVariance(a)

biased = BiasedVarianceList(a)
        

unbias = np.mean(biased) - theta
    
    
# def BiasedVariableBias(data):
#     """
#     """
#     actual = 2 # Estimate population sampling of 2, as indicated on the handout
#     l = []
#     value = None
#     for i in range(len(data)):
#         value = data[i] - actual
# #         print(value)
#         l.append(value)
#     return l

# print("Values for all 125 distributions of Bias[a^2]:")
# print('-------------------------------------------------')

        
# theta_hat = BiasedVariableBias(biased)

# np.mean(theta_hat) - theta
# np.mean(biased) - theta


print("Bias[a^2]:")
print(bias)

# theta_hat = UnBiasedVariableBias(unbiased)
# print(theta_hat)

# np.mean(theta_hat) - theta

print('-------------------------------------------------')

print ("Bias[a^2]: {}. For instance, this satisfies the biasedness condition where the expectation of estimator of \
theta minus theta is not equal to zero. This case, it underestimates. Therefore, a^2, consistent with the definition,\
is biased.".format(bias))
# Out:
# Bias[a^2]:
# -0.6666666666666667
# -------------------------------------------------
# Bias[a^2]: -0.6666666666666667. For instance, this satisfies the biasedness condition where the expectation of estimator of theta minus theta is not equal to zero. This case, it underestimates. Therefore, a^2, consistent with the definition,is biased.

# %% [markdown]
# b) $MSE[\hat{\sigma}^2] = var[\hat{\sigma}^2] + (Bias[\hat{\sigma}^2])^2$ <br>
#    * We will check the identity of this by calculating all three parts seperatly.

# %% [markdown]
# The MSE of an unbiased population variance is $MSE[T] = E[(T - \theta)^2]$, where $T$ is an estimator for $\theta$.
# We know that theta is 2, according to the handout. Below is an MSE decomposition.

# %%
import numpy as np
# theta = 2
# print(theta_hat)

# def BiasedVariableBias2(data):
#     """
#     """
#     theta = 2
#     print(np.mean(data))
#     bias = np.mean(data) - theta
#     return [bias]
        
# def popmean(data):
#     l = []
#     for i in range(len(data)):
#         l.append(np.mean(data[i]))
#     return l
    
# popmean(a)
# u = popmean(BiasedVariableBias(biased))

u = BiasedVarianceList(a)

theta_hat = np.asarray(u)  #estimator

mse = np.mean(np.square(theta-theta_hat))

var = np.var(theta_hat)
bias = np.mean(theta_hat) - theta

print("MSE result:", mse)
print("Variance:", var)
print("Bias:", bias * bias)
print("Decomposed result:", var + bias*bias)
# Out:
# MSE result: 1.4518518518518517
# Variance: 1.0074074074074075
# Bias: 0.44444444444444453
# Decomposed result: 1.4518518518518522
