[25,   25,   25]]

# %% [markdown]
# a) OUTPUT BELOW:

# %%
import statistics as st

# def unbiasedvar(data):
#     for i in range(len(data)):
# #         print(data[a])
#         print(st.pvariance(data[i]))
# unbiasedvar(a)
        
# st.pvariance(a)

# myUnbiasedVariance(a)
def myUnVariance(data):
    # finds the variance of a given set of numbers
    for i in range(len(data)):
        xbar = st.mean(data[i])
        var = sum([(x - xbar)**2 for x in data[i]])/(len(data[i]))
        print(var)
        
print('--------------------------------------------------------------')


myUnVariance(a)
# Out:
# --------------------------------------------------------------
# 0.0
# 0.22222222222222224
# 0.8888888888888888
# 2.0
# 3.555555555555556
# 0.22222222222222224
# 0.22222222222222224
# 0.6666666666666666
# 1.5555555555555554
# 2.8888888888888893
# 0.8888888888888888
# 0.6666666666666666
# 0.8888888888888888
# 1.5555555555555554
# 2.6666666666666665
# 2.0
# 1.5555555555555554
# 1.5555555555555554
# 2.0
# 2.8888888888888893
# 3.555555555555556
# 2.8888888888888893
# 2.6666666666666665
# 2.8888888888888893
# 3.555555555555556
# 0.22222222222222224
# 0.22222222222222224
# 0.6666666666666666
# 1.5555555555555556
# 2.8888888888888893
# 0.22222222222222224
# 0.0
# 0.22222222222222224
# 0.8888888888888888
# 2.0
# 0.6666666666666666
# 0.22222222222222224
# 0.22222222222222224
# 0.6666666666666666
# 1.5555555555555554
# 1.5555555555555556
# 0.8888888888888888
# 0.6666666666666666
# 0.8888888888888888
# 1.5555555555555554
# 2.8888888888888893
# 2.0
# 1.5555555555555554
# 1.5555555555555554
# ...

# %%
# def myUnbiasedVariance(data):
#     # finds the 'unbiased' variance of a given set of numbers (divides by N-1) 
#     xbar = st.mean(data)
#     return sum([(x - xbar)**2 for x in data])/(len(data)-1)

# myUnbiasedVariance(a)
def myUnVariance(data):
    # finds the variance of a given set of numbers
    for i in range(len(data)):
        xbar = st.mean(data[i])
        var = sum([(x - xbar)**2 for x in data[i]])/(len(data[i]) -1)
        print(var)
        
print("The unbiased means of the 125 different datas are the below:")
print('--------------------------------------------------------------')


myUnVariance(a)
# Out:
# The unbiased means of the 125 different datas are the below:
# --------------------------------------------------------------
# 0.0
# 0.33333333333333337
# 1.3333333333333333
# 3.0
# 5.333333333333334
# 0.33333333333333337
# 0.33333333333333337
# 1.0
# 2.333333333333333
# 4.333333333333334
# 1.3333333333333333
# 1.0
# 1.3333333333333333
# 2.333333333333333
# 4.0
# 3.0
# 2.333333333333333
# 2.333333333333333
# 3.0
# 4.333333333333334
# 5.333333333333334
# 4.333333333333334
# 4.0
# 4.333333333333334
# 5.333333333333334
# 0.33333333333333337
# 0.33333333333333337
# 1.0
# 2.3333333333333335
# 4.333333333333334
# 0.33333333333333337
# 0.0
# 0.33333333333333337
# 1.3333333333333333
# 3.0
# 1.0
# 0.33333333333333337
# 0.33333333333333337
# 1.0
# 2.333333333333333
# 2.3333333333333335
# 1.3333333333333333
# 1.0
# 1.3333333333333333
# 2.333333333333333
# 4.333333333333334
# 3.0
# 2.333333333333333
# 2.333333333333333
# 3.0
# 1.3333333333333333
# 1.0
# 1.3333333333333333
# 2.3333333333333335
# ...

# %% [markdown]
# a) Below is the Calculation of the $Bias[S^2]$ and $Bias[\hat{\sigma}^2]$ for all 125 distributions.<BR>
#    OUTPUT BELOW:

# %%
def UnBiasedVarianceList(data):
    # finds the variance of a given set of numbers
    l = []
    for i in range(len(data)):
        xbar = st.mean(data[i])
        var = sum([(x - xbar)**2 for x in data[i]])/(len(data[i]) - 1) # Unbiased
        l.append(var)
    return l

unbiased = UnBiasedVarianceList(a)

# np.mean(unbiased)
        
# def UnBiasedVariableBias(data):
#     """
#     """
# #     theta = 2
# #     print(np.mean(data))
# #     bias = np.mean(data) - theta
# #     return bias
#     actual = 2 # Estimate population sampling of 2, as indicated on the handout
#     value = None
#     l = []
#     for i in range(len(data)):
#         value = data[i] - actual
# #         print(value)
#         l.append(value)
#     return l

# print("Bias[S^2]:")
# print('-------------------------------------------------')

        

# theta_hat = UnBiasedVariableBias(unbiased)
# print(theta_hat)

# np.mean(theta_hat) - theta

np.mean(unbiased) - theta
# Out:
# 4.440892098500626e-16

# %%
def BiasedVarianceList(data):
    # finds the variance of a given set of numbers
    l = []
    for i in range(len(data)):
        xbar = st.mean(data[i])
        var = sum([(x - xbar)**2 for x in data[i]])/(len(data[i]))
        l.append(var)
    return l
# myVariance(a)

biased = BiasedVarianceList(a)
        

# def BiasedVariableBias(data):
#     """
#     """
#     actual = 2 # Estimate population sampling of 2, as indicated on the handout
#     l = []
#     value = None
#     for i in range(len(data)):
#         value = data[i] - actual
# #         print(value)
#         l.append(value)
#     return l

# print("Values for all 125 distributions of Bias[a^2]:")
# print('-------------------------------------------------')

        
# theta_hat = BiasedVariableBias(biased)

# np.mean(theta_hat) - theta
np.mean(biased) - theta
# Out:
# -0.6666666666666667

# %% [markdown]
# b) $MSE[\hat{\sigma}^2] = var[\hat{\sigma}^2] + (Bias[\hat{\sigma}^2])^2$ <br>
#    * We will check the identity of this by calculating all three parts seperatly.

# %% [markdown]
# The MSE of an unbiased population variance is $MSE[T] = E[(T - \theta)^2]$, where $T$ is an estimator for $\theta$.
# We know that theta is 2, according to the handout. Below is an MSE decomposition.

# %%
import numpy as np
theta = 2
# print(theta_hat)

# def BiasedVariableBias2(data):
#     """
#     """
#     theta = 2
#     print(np.mean(data))
#     bias = np.mean(data) - theta
#     return [bias]
        
# def popmean(data):
#     l = []
#     for i in range(len(data)):
#         l.append(np.mean(data[i]))
#     return l
    
# popmean(a)
# u = popmean(BiasedVariableBias(biased))

u = popmean(BiasedVariableBias(biased))

theta_hat = np.asarray(u)  #estimator

mse = np.mean(np.square(theta-theta_hat))

var = np.var(theta_hat)
bias = np.mean(theta_hat) - theta

print("MSE result:", mse)
print("Variance:", var)
print("Bias:", bias * bias)
print("Decomposed result:", var + bias*bias)
# Out:
# MSE result: 8.118518518518519
# Variance: 1.0074074074074078
# Bias: 7.111111111111111
# Decomposed result: 8.118518518518519

# %%
# print(unbiased)
print(np.var(biased))
# Out:
# 1.0074074074074075
