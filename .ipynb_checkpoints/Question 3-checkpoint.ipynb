# %% [markdown]
# ## Question 3 ##

# %%
sample_4m_normal=function(){
  
  s=rnorm(30, mean=10,sd=2)        # drawing 30 random numbers from N(10,2^2)
  x_bar=mean(s)
  
  return(x_bar)                  # returning the mean of my sample of size 30
}

X_bar=replicate(1000000, sample_4m_normal())

plot(density(X_bar))
# Out:
# Plot with title “density.default(x = X_bar)”

# %% [markdown]
# a) OUTPUT BELOW:

# %%
sample_4m_normal=function(){
  
  s=runif(2, 0,1)        # Uniform distribution of n = 2, min =0, max = 1
  x_bar=mean(s)
  
  return(x_bar)                  
}

X_bar=replicate(1000000, sample_4m_normal())

plot(density(X_bar))
# Out:
# Plot with title “density.default(x = X_bar)”

# %% [markdown]
# b) OUTPUT BELOW:

# %%
sample_4m_normal=function(){
  
  s=runif(5, 0,1)        # uniform distribution of n = 5, min = 0, max = 1
  x_bar=mean(s)
  
  return(x_bar)                  
}

X_bar=replicate(1000000, sample_4m_normal())

plot(density(X_bar))
# Out:
# Plot with title “density.default(x = X_bar)”

# %% [markdown]
# c) OUTPUT BELOW:

# %%
sample_4m_normal=function(){
  
  s=rchisq(2, 2)        # Chi-Square distribution of n = 2 with df = 2
  x_bar=mean(s)
  
  return(x_bar)                  
}

X_bar=replicate(1000000, sample_4m_normal())

plot(density(X_bar))
# Out:
# Plot with title “density.default(x = X_bar)”

# %% [markdown]
# d) OUTPUT BELOW:

# %%
sample_4m_normal=function(){
  
  s=rchisq(30, 2)        # Chi-Square distribution of n = 30 with df = 2
  x_bar=mean(s)
  
  return(x_bar)                  
}

X_bar=replicate(1000000, sample_4m_normal())

plot(density(X_bar))
# Out:
# Plot with title “density.default(x = X_bar)”

# %% [markdown]
# e) OUTOUT BELOW:

# %%
sample_4m_normal=function(){
  
  s=rchisq(5, 50)        # Chi-Square distribution of n = 5 with df = 50
  x_bar=mean(s)
  
  return(x_bar)                  
}

X_bar=replicate(1000000, sample_4m_normal())

plot(density(X_bar))
# Out:
# Plot with title “density.default(x = X_bar)”

# %% [markdown]
# f) While it is hard to comment on the exact value of n as we are already have graphed the above on a sample size of 1000000, we know that according to the CLT, as n approaches infinity, every distribution will converge to a normal distribution. Thus, we can say that n has to be as large as possible.

# %% [markdown]
# g) OUTPUT BELOW:

# %%
plot(density(runif(100000, 0, 1)))
# Out:
# Plot with title “density.default(x = runif(1e+05, 0, 1))”

# %%
plot(density(rchisq(100000, 0, 1)))
